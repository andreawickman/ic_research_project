# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

from src.rf import feature_selection_and_plot

# %%
#LOAD DATASETS
train = pd.read_csv('./data/derived/feature_selection/training_data.csv', index_col=0)
test = pd.read_csv('./data/derived/feature_selection/test_data.csv', index_col=0)
combined = pd.concat([train, test])

# Convert TSI_days to TSI_years
combined['TSI_years'] = combined['TSI_days'] / 365

# Transform TSI_years using the square root
combined['sqrt_TSI_years'] = np.sqrt(combined['TSI_years'])

# %%
#DEFINE X AND Y
X_train = combined.drop(columns=['sqrt_TSI_years', 'TSI_years', 'TSI_category', 'TSI_days', 'RENAME_ID'])
y_train = combined['sqrt_TSI_years']

# %%
selected_features = feature_selection_and_plot(X_train, y_train, model_type = RandomForestRegressor, output_path= './outputs/features/feature_importance_regressor.png')
# Out:
# Complete set of features: ['genome_lrtt', 'genome_tips', 'gag_lrtt', 'gag_tips', 'pol_lrtt', 'pol_tips', 'gp120_lrtt', 'gp120_tips', 'gp41_lrtt', 'gp41_tips', 'genome_maf12c', 'genome_maf3c', 'gag_maf12c', 'gag_maf3c', 'pol_maf12c', 'pol_maf3c', 'gp120_maf12c', 'gp120_maf3c', 'gp41_maf12c', 'gp41_maf3c', 'genome_ambig', 'gag_ambig', 'pol_ambig', 'gp41_ambig', 'gp120_ambig']
# Selected features: ['genome_lrtt', 'genome_tips', 'gag_lrtt', 'gag_tips', 'pol_lrtt', 'pol_tips', 'gp120_lrtt', 'gp120_tips', 'gp41_lrtt', 'gp41_tips', 'genome_maf12c', 'genome_maf3c', 'gag_maf12c', 'gag_maf3c', 'pol_maf12c', 'pol_maf3c', 'gp120_maf12c', 'gp120_maf3c', 'gp41_maf12c', 'gp41_maf3c', 'genome_ambig', 'gag_ambig', 'pol_ambig', 'gp41_ambig', 'gp120_ambig']

# %%
len(selected_features)
# Out:
# 25

# %% [markdown]
# ## WITH BSPLINE COEFFICIENTS

# %%
#LOAD DATASETS
train = pd.read_csv('./data/derived/bspline_coeffs/training_data_with_bspline_coeffs.csv', index_col=0)
test = pd.read_csv('./data/derived/bspline_coeffs/test_data_with_bspline_coeffs.csv', index_col=0)
combined = pd.concat([train, test])

# Convert TSI_days to TSI_years
combined['TSI_years'] = combined['TSI_days'] / 365

# Transform TSI_years using the square root
combined['sqrt_TSI_years'] = np.sqrt(combined['TSI_years'])

#DEFINE X AND Y
X_train = combined.drop(columns=['sqrt_TSI_years', 'TSI_years', 'TSI_category', 'TSI_days', 'RENAME_ID'])
y_train = combined['sqrt_TSI_years']

# %%
selected_features = feature_selection_and_plot(X_train, y_train, model_type = RandomForestRegressor, output_path= './outputs/features/feature_importance_regressor_with_bspline_coeffs.png')
# Out:
# Complete set of features: ['genome_lrtt', 'genome_tips', 'gag_lrtt', 'gag_tips', 'pol_lrtt', 'pol_tips', 'gp120_lrtt', 'gp120_tips', 'gp41_lrtt', 'gp41_tips', 'genome_maf12c', 'genome_maf3c', 'gag_maf12c', 'gag_maf3c', 'pol_maf12c', 'pol_maf3c', 'gp120_maf12c', 'gp120_maf3c', 'gp41_maf12c', 'gp41_maf3c', 'lrtt_coeff_0', 'lrtt_coeff_1', 'lrtt_coeff_2', 'lrtt_coeff_3', 'lrtt_coeff_4', 'lrtt_coeff_5', 'lrtt_coeff_6', 'lrtt_coeff_7', 'lrtt_coeff_8', 'lrtt_coeff_9', 'lrtt_coeff_10', 'lrtt_coeff_11', 'maf12c_coeff_0', 'maf12c_coeff_1', 'maf12c_coeff_2', 'maf12c_coeff_3', 'maf12c_coeff_4', 'maf12c_coeff_5', 'maf12c_coeff_6', 'maf12c_coeff_7', 'maf12c_coeff_8', 'maf12c_coeff_9', 'maf12c_coeff_10', 'maf12c_coeff_11', 'maf3c_coeff_0', 'maf3c_coeff_1', 'maf3c_coeff_2', 'maf3c_coeff_3', 'maf3c_coeff_4', 'maf3c_coeff_5', 'genome_ambig', 'gag_ambig', 'pol_ambig', 'gp41_ambig', 'gp120_ambig']
# ...

# %%
len(selected_features) #46 of 55
# Out:
# 46

# %% [markdown]
# # For LOG TRANSFORMATION

# %%
#LOAD DATASETS
train = pd.read_csv('./data/derived/feature_selection/training_data_with_dual.csv', index_col=0)
test = pd.read_csv('./data/derived/feature_selection/test_data_with_dual.csv', index_col=0)
combined = pd.concat([train, test])

# Convert TSI_days to TSI_years
combined['TSI_years'] = combined['TSI_days'] / 365
# Transform TSI_years using the square root
combined['log_TSI_years'] = np.log1p(combined['TSI_years'])

#DEFINE X AND Y
X_train = combined.drop(columns=['log_TSI_years', 'TSI_years', 'TSI_category', 'TSI_days', 'RENAME_ID'])
y_train = combined['log_TSI_years']

# %%
selected_features_log = feature_selection_and_plot(X_train, y_train, model_type = RandomForestRegressor, output_path= './outputs/features/feature_importance_regressor_log.png')
# Out:
# Complete set of features: ['genome_lrtt', 'genome_tips', 'genome_dual', 'genome_reads', 'gag_lrtt', 'gag_tips', 'gag_dual', 'gag_reads', 'pol_lrtt', 'pol_tips', 'pol_dual', 'pol_reads', 'gp120_lrtt', 'gp120_tips', 'gp120_dual', 'gp120_reads', 'gp41_lrtt', 'gp41_tips', 'gp41_dual', 'gp41_reads', 'genome_maf12c', 'genome_maf3c', 'gag_maf12c', 'gag_maf3c', 'pol_maf12c', 'pol_maf3c', 'gp120_maf12c', 'gp120_maf3c', 'gp41_maf12c', 'gp41_maf3c', 'lrtt_coeff_0', 'lrtt_coeff_1', 'lrtt_coeff_2', 'lrtt_coeff_3', 'lrtt_coeff_4', 'lrtt_coeff_5', 'lrtt_coeff_6', 'lrtt_coeff_7', 'lrtt_coeff_8', 'lrtt_coeff_9', 'lrtt_coeff_10', 'lrtt_coeff_11', 'maf12c_coeff_0', 'maf12c_coeff_1', 'maf12c_coeff_2', 'maf12c_coeff_3', 'maf12c_coeff_4', 'maf12c_coeff_5', 'maf12c_coeff_6', 'maf12c_coeff_7', 'maf12c_coeff_8', 'maf12c_coeff_9', 'maf12c_coeff_10', 'maf12c_coeff_11', 'maf3c_coeff_0', 'maf3c_coeff_1', 'maf3c_coeff_2', 'maf3c_coeff_3', 'maf3c_coeff_4', 'maf3c_coeff_5', 'genome_ambig', 'gag_ambig', 'pol_ambig',
# ...

# %%
len(selected_features_log)
# Out:
# 44
